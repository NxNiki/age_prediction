# %%
# run script02_age_prediction_disorders for all four methods and show regression rfe results in one file:
import pandas as pd

# regression_rfe_table_dnn = pd.read_csv("result/disorders/regression_rfe_DNN_GMV&DTI.csv")
# regression_rfe_table_ridge = pd.read_csv("result/disorders/regression_rfe_Ridge_GMV&DTI.csv")
# regression_rfe_table_gpr = pd.read_csv("result/disorders/regression_rfe_GPR_GMV&DTI.csv")
# regression_rfe_table_svr = pd.read_csv("result/disorders/regression_rfe_SVR_GMV&DTI.csv") 

regression_rfe_table_dnn = pd.read_csv("result/disorders/regression_rfe_DNN_Multi-modal.csv")
regression_rfe_table_ridge = pd.read_csv("result/disorders/regression_rfe_Ridge_Multi-modal.csv")
regression_rfe_table_gpr = pd.read_csv("result/disorders/regression_rfe_GPR_Multi-modal.csv")
regression_rfe_table_svr = pd.read_csv("result/disorders/regression_rfe_SVR_Multi-modal.csv")

# %%
regression_rfe_table_dnn=regression_rfe_table_dnn.reindex([2, 0, 1, 3, 4, 5])
regression_rfe_table_dnn
# Out:
#       Unnamed: 0      PTSD  Depression  Specific Phobia  Social Phobia  \
# 2            age       NaN         NaN        -1.083849       -0.95692
# 0  SMEM_Accuracy  0.699012         NaN              NaN            NaN
# 1   NVR_Accuracy       NaN   -0.789310              NaN            NaN
# 3     VMEM_Speed       NaN         NaN              NaN            NaN
# 4       rsquared  0.064241    0.099528         0.170442        0.11466
# 5            NaN       NaN         NaN              NaN            NaN
#
#    Agroaphobia
# 2          NaN
# 0          NaN
# 1          NaN
# 3     1.213077
# 4     0.224044
# 5          NaN

# %%
regression_rfe_table_ridge
# Out:
#      Unnamed: 0      PTSD  Depression  Specific Phobia  Social Phobia  \
# 0           age -1.116861         NaN        -1.245226      -1.099198
# 1  NVR_Accuracy       NaN   -0.552467              NaN            NaN
# 2  ADI_Accuracy       NaN         NaN              NaN            NaN
# 3      rsquared  0.204533    0.063693         0.246028       0.175176
#
#    Agroaphobia
# 0          NaN
# 1          NaN
# 2    -0.461517
# 3     0.047283

# %%
regression_rfe_table_gpr
# Out:
#   Unnamed: 0      PTSD  Depression  Specific Phobia  Social Phobia  \
# 0        age -1.272772   -0.855982        -1.299100      -1.121240
# 1   rsquared  0.290456    0.159505         0.284973       0.195159
#
#    Agroaphobia
# 0    -0.860201
# 1     0.209448

# %%
regression_rfe_table_svr
# Out:
#   Unnamed: 0      PTSD  Depression  Specific Phobia  Social Phobia  \
# 0        age -1.331238         NaN        -1.370940      -1.177793
# 1  EDI_Speed       NaN   -0.579228              NaN            NaN
# 2   rsquared  0.307651    0.062435         0.305187       0.213998
#
#    Agroaphobia
# 0    -0.942873
# 1          NaN
# 2     0.252825
